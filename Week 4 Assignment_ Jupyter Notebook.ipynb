# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Michael Varesio
# Desired Occupation: Data Scientist

# %% [markdown]
# ##### I am interested in data science because I enjoy finding patterns in perceived chaos.

# %% [markdown]
# ### The next cell code will show the result of adding two numbers

# %%
29004 + 29004
# Out:
# 58008

# %% [markdown]
# | Header | Header | Header |
# | ------ | ------ | ------ |
# | 1 | 2 | 3 |
# | 4 | 5 | 6 |
# ~~Strikethrough~~
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
